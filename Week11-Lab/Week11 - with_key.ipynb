# %% [markdown]
# # Week 11 - Social Data Mining 2

# %% [markdown]
# ## 1. Twitter 데이터 수집하기
#
# 트위터는 데이터를 수집할 수 있는 API를 제공한다. API는 크게 다음과 같은 두가지로 제공된다.
# * REST API - 주어진 query에 맞는 데이터를 제공한다.
# * Streaming API - 제시된 키워드 등이 포함된 데이터를 streaming 해준다.
#
# 트위터 API에 대응하는 여러 라이브러리가 있지만, 본 예제에서는 tweepy 를 사용한다. tweepy의 설치는 다음과 같다.
# * pip install tweepy
#
# 트위터는 OAuth 인증을 통해 데이터에 접근이 가능하다. OAuth 인증을 하기 위해서는 트위터 개발자 사이트에 등록하고, 데이터 수집을 위한 앱을 등록해야 한다. 등록을 마치면 OAuth 인증을 위한 키가 제공되는데 해당 키를 이용하여 트위터 API를 사용할 수 있다.
#
# (강의 슬라이드 참고)

# %% [markdown]
# ### tweepy 및 OAuth 설정

# %%
import tweepy

# OAuth setup
consumer_key = 'bw5hox6zAolb8vJrMcE0jjgk7'
consumer_secret = 'Py0I2s2qerylZlViWVxtxvDbnj3Juo1TPTT0GiJxu7stVhSDXV'
access_token = '1193801853923758080-Kl4FlscU99SJljxFMdsDOlBxH0UXe4'
access_secret = '2enFNME8mZiVrEP9DzgdpTjZ7yEsG9kJtvNH6j80XwlbU'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

# %% [markdown]
# ### tweepy api 오브젝트 생성

# %%
api = tweepy.API(auth) # initialize

# %%
my_timeline = api.home_timeline()
my_timeline

# for tweet in my_timeline:
#     print(tweet.text)
# Out:
# []

# %% [markdown]
# ### 특정 사용자의 타임라인 수집

# %%
user = api.get_user("u_simin")
user
# Out:
# User(_api=<tweepy.api.API object at 0x1053b9dd0>, _json={'id': 102026929, 'id_str': '102026929', 'name': '유시민', 'screen_name': 'u_simin', 'location': 'korea', 'profile_location': None, 'description': '문필업에 종사하는 정의당 평당원,\r\n청춘의 독서, 국가란 무엇인가, 어떻게 살 것인가 저자', 'url': 'http://t.co/Zc7QTMzj4Y', 'entities': {'url': {'urls': [{'url': 'http://t.co/Zc7QTMzj4Y', 'expanded_url': 'http://usimin.net/', 'display_url': 'usimin.net', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 572710, 'friends_count': 33354, 'listed_count': 14801, 'created_at': 'Tue Jan 05 10:42:07 +0000 2010', 'favourites_count': 21, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 1195, 'lang': None, 'status': {'created_at': 'Wed Nov 19 05:54:37 +0000 2014', 'id': 534947835792216064, 'id_str': '534947835792216064', 'text': '정말 유익한 강연. 뇌과학에 입각한 철학의 재정립. 강추!!!RT @windqkfka: @noyujincafe 김대식 카이스트 교수 &lt;뇌,나,그리고 현실&gt; http://t.co/BLFPCXnwCl', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'windqkfka', 'name': '자유로운 시민, 정의로운 나라', 'id': 285455818, 'id_str': '285455818', 'indices': [37, 47]}, {'screen_name': 'noyujincafe', 'name': '정치카페', 'id': 2583074244, 'id_str': '2583074244', 'indices': [49, 61]}], 'urls': [{'url': 'http://t.co/BLFPCXnwCl', 'expanded_url': 'http://www.yanghwajin.re.kr/html/vod/vod_640.php?id=m_lectures&no=185', 'display_url': 'yanghwajin.re.kr/html/vod/vod_6…', 'indices': [93, 115]}]}, 'source': '<a href="http://twtkr.com" rel="nofollow">twtkr</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 414, 'favorite_count': 1041, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'ko'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/633306634/tweet_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/633306634/tweet_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, id=102026929, id_str='102026929', name='유시민', screen_name='u_simin', location='korea', profile_location=None, description='문필업에 종사하는 정의당 평당원,\r\n청춘의 독서, 국가란 무엇인가, 어떻게 살 것인가 저자', url='http://t.co/Zc7QTMzj4Y', entities={'url': {'urls': [{'url': 'http://t.co/Zc7QTMzj4Y', 'expanded_url': 'http://usimin.net/', 'display_url': 'usimin.net', 'indices': [0, 22]}]}, 'description': {'urls': []}}, protected=False, followers_count=572710, friends_count=33354, listed_count=14801, created_at=datetime.datetime(2010, 1, 5, 10, 42, 7), favourites_count=21, utc_offset=None, time_zone=None, geo_enabled=True, verified=False, statuses_count=1195, lang=None, status=Status(_api=<tweepy.api.API object at 0x1053b9dd0>, _json={'created_at': 'Wed Nov 19 05:54:37 +0000 2014', 'id': 534947835792216064, 'id_str': '534947835792216064', 'text': '정말 유익한 강연. 뇌과학에 입각한 철학의 재정립. 강추!!!RT @windqkfka: @noyujincafe 김대식 카이스트 교수 &lt;뇌,나,그리고 현실&gt; http://t.co/BLFPCXnwCl', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'windqkfka', 'name': '자유로운 시민, 정의로운 나라', 'id': 285 ...

# %%
user.id
user.description
user.created_at
# Out:
# datetime.datetime(2010, 1, 5, 10, 42, 7)

# %%
user = api.get_user(102026929)  # 만약 screen_name이 아닌 id를 알고 있다면

# %%
user_timeline = api.user_timeline(user.id)
# print(user_timeline[0])
tweets = []
for tweet in user_timeline:
    tweets.append(tweet)

# %%
tweets[1].text
tweets[1].user
tweets[1].user.name
tweets[1]._json
# Out:
# {'created_at': 'Fri Oct 10 11:23:31 +0000 2014',
#  'id': 520535089776574464,
#  'id_str': '520535089776574464',
#  'text': '죄송...전남진 시인 맞아요..',
#  'truncated': False,
#  'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#  'source': '<a href="http://novly.com/parang" rel="nofollow">파랑새</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 102026929,
#   'id_str': '102026929',
#   'name': '유시민',
#   'screen_name': 'u_simin',
#   'location': 'korea',
#   'description': '문필업에 종사하는 정의당 평당원,\r\n청춘의 독서, 국가란 무엇인가, 어떻게 살 것인가 저자',
#   'url': 'http://t.co/Zc7QTMzj4Y',
#   'entities': {'url': {'urls': [{'url': 'http://t.co/Zc7QTMzj4Y',
#       'expanded_url': 'http://usimin.net/',
#       'display_url': 'usimin.net',
#       'indices': [0, 22]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 572710,
#   'friends_count': 33354,
#   'listed_count': 14801,
#   'created_at': 'Tue Jan 05 10:42:07 +0000 2010',
#   'favourites_count': 21,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 1195,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/633306634/tweet_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/633306634/tweet_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'can_media_tag': True,
#   'followed_by': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 108,
#  'favorite_count': 296,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'ko'}

# %% [markdown]
# ### 특정 유저의 친구 목록

# %%
user = api.get_user("Yunaaaa")
user.screen_name
user.followers_count # 너무 많아서 못함
user.friends_count # 김연아가 팔로워한 사람들
# Out:
# 10

# %%
for friend in user.friends():
    print(friend.screen_name)
# Out:
# youtholympics
# rainappsocial
# ImageShack
# climbjain
# pyeongchang2018
# Pchiddy
# j3r3bear
# cantufeelicks
# Rachelka92
# Adaripp

# %% [markdown]
# (주의) user.followers()는 모두 665714 명이다. 트위터 API는 15분간 15개의 request call을 허용한다. 한번의 request 마다 20개의 followers를 가져온다면 모두 약 44381여개의 call이 필요하기 때문에 rate limit을 넘어서게 된다. 따라서 이 경우는 15개를 가져오고 잠시 쉬었다가 다시 가져오는 등의 방법을 사용한다. 처리 방법은 뒤에서 다루고 여기서는 call을 많이 사용하지 않는 friends의 리스트를 가져와 보았다.
#
# https://dev.twitter.com/rest/public/rate-limiting

# %% [markdown]
# ### Pagination and Cursor
#
# 트위터의 정보는 pagination 되어 있다. page를 넘겨가며 데이터를 수집하기 위해서는 cursor 를 사용한다. Cursor는 다음과 같이 사용한다.

# %%
my_tweets = []
for tweet in tweepy.Cursor(api.user_timeline, id="u_simin").items(10): # pagination한 것 중에, 10개의 데이터만 수집
    my_tweets.append(tweet)
    
my_tweets
# Out:
# [Status(_api=<tweepy.api.API object at 0x1053b9dd0>, _json={'created_at': 'Wed Nov 19 05:54:37 +0000 2014', 'id': 534947835792216064, 'id_str': '534947835792216064', 'text': '정말 유익한 강연. 뇌과학에 입각한 철학의 재정립. 강추!!!RT @windqkfka: @noyujincafe 김대식 카이스트 교수 &lt;뇌,나,그리고 현실&gt; http://t.co/BLFPCXnwCl', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'windqkfka', 'name': '자유로운 시민, 정의로운 나라', 'id': 285455818, 'id_str': '285455818', 'indices': [37, 47]}, {'screen_name': 'noyujincafe', 'name': '정치카페', 'id': 2583074244, 'id_str': '2583074244', 'indices': [49, 61]}], 'urls': [{'url': 'http://t.co/BLFPCXnwCl', 'expanded_url': 'http://www.yanghwajin.re.kr/html/vod/vod_640.php?id=m_lectures&no=185', 'display_url': 'yanghwajin.re.kr/html/vod/vod_6…', 'indices': [93, 115]}]}, 'source': '<a href="http://twtkr.com" rel="nofollow">twtkr</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 102026929, 'id_str': '102026929', 'name': '유시민', 'screen_name': 'u_simin', 'location': 'korea', 'description': '문필업에 종사하는 정의당 평당원,\r\n청춘의 독서, 국가란 무엇인가, 어떻게 살 것인가 저자', 'url': 'http://t.co/Zc7QTMzj4Y', 'entities': {'url': {'urls': [{'url': 'http://t.co/Zc7QTMzj4Y', 'expanded_url': 'http://usimin.net/', 'display_url': 'usimin.net', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 572710, 'friends_count': 33354, 'listed_count': 14801, 'created_at': 'Tue Jan 05 10:42:07 +0000 2010', 'favourites_count': 21, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 1195, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/633306634/tweet_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/633306634/tweet_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 414, 'favorite_count': 1041, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'ko'}, created_at=datetime.datetime(2014, 11, 19, 5, 54, 37), id=534947835792216064, id_str='534947835792216064', text='정말 유익한 강연. 뇌과학에 입각한 철학의 재정립. 강추!!!RT @windqkfka: @noyujincafe 김대식 카이스트 교수 &lt;뇌,나,그리고 현실&gt; http://t.co/BLFPCXnwCl', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'windqkfka', 'name': '자유로운 시민, 정의로운 나라', 'id': 285455818, 'id_str': '285455818', 'indices': [37, 47]}, {'screen_name': 'noyujincafe', 'name': '정치카페', 'id': 2583074244, 'id_str': '2583074244', 'indices': [49, 61]}], 'urls': [{'url': 'http://t.co/BLFPCXnwCl', 'expanded_url': 'http://www.yanghwajin.re.kr/html/vod/vod_640.php?id=m_lectures&no=185', 'display_url': 'yanghwajin.re.kr/html/vod/vod_6…', 'indices': [93, 115]}]}, source='twtkr', source_url='http://twtkr.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x1053b9dd0>, _json={'id': 102026929, 'id_str': '102026929', 'name': '유시민', 'screen_name': 'u_simin', 'location': 'korea', 'descriptio ...
#  Status(_api=<tweepy.api.API object at 0x1053b9dd0>, _json={'created_at': 'Fri Oct 10 11:23:31 +0000 2014', 'id': 520535089776574464, 'id_str': '520535089776574464', 'text': '죄송...전남진 시인 맞아요..', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="http://novly.com/parang" rel="nofollow">파랑새</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 102026929, 'id_str': '102026929', 'name': '유시민', 'screen_name': 'u_simin', 'location': 'korea', 'description': '문필업에 종사하는 정의당 평당원,\r\n청춘의 독서, 국가란 무엇인가, 어떻게 살 것인가 저자', 'url': 'http://t.co/Zc7QTMzj4Y', 'entities': {'url': {'urls': [{'url': 'http://t.co/Zc7QTMzj4Y', 'expanded_url': 'http://usimin.net/', 'display_url': 'usimin.net', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 572710, 'friends_count': 33354, 'listed_count': 14801, 'created_at': 'Tue Jan 05 10:42:07 +0000 2010', 'favourites_count': 21, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 1195, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/633306634/tweet_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/633306634/tweet_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 108, 'favorite_count': 296, 'favorited': False, 'retweeted': False, 'lang': 'ko'}, created_at=datetime.datetime(2014, 10, 10, 11, 23, 31), id=520535089776574464, id_str='520535089776574464', text='죄송...전남진 시인 맞아요..', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='파랑새', source_url='http://novly.com/parang', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x1053b9dd0>, _json={'id': 102026929, 'id_str': '102026929', 'name': '유시민', 'screen_name': 'u_simin', 'location': 'korea', 'description': '문필업에 종사하는 정의당 평당원,\r\n청춘의 독서, 국가란 무엇인가, 어떻게 살 것인가 저자', 'url': 'http://t.co/Zc7QTMzj4Y', 'entities': {'url': {'urls': [{'url': 'http://t.co/Zc7QTMzj4Y', 'expanded_url': 'http://usimin.net/', 'display_url': 'usimin.net', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 572710, 'friends_count': 33354, 'listed_count': 14801, 'created_at': 'Tue Jan 05 10:42:07 +0000 2010', 'favourites_count': 21, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 1195, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/633306634/tweet_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/633306634/twee ...
#  Status(_api=<tweepy.api.API object at 0x1053b9dd0>, _json={'created_at': 'Fri Oct 10 09:11:39 +0000 2014', 'id': 520501907983327232, 'id_str': '520501907983327232', 'text': '오랫만에 강릉 나들이..전남주시인의 모모카페에서 커피한잔. 좋네요..그런데 왜?? 사진이 업로드가 자꾸만 에러가나네요 ㅠㅠ', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="http://novly.com/parang" rel="nofollow">파랑새</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 102026929, 'id_str': '102026929', 'name': '유시민', 'screen_name': 'u_simin', 'location': 'korea', 'description': '문필업에 종사하는 정의당 평당원,\r\n청춘의 독서, 국가란 무엇인가, 어떻게 살 것인가 저자', 'url': 'http://t.co/Zc7QTMzj4Y', 'entities': {'url': {'urls': [{'url': 'http://t.co/Zc7QTMzj4Y', 'expanded_url': 'http://usimin.net/', 'display_url': 'usimin.net', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 572710, 'friends_count': 33354, 'listed_count': 14801, 'created_at': 'Tue Jan 05 10:42:07 +0000 2010', 'favourites_count': 21, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 1195, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/633306634/tweet_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/633306634/tweet_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 131, 'favorite_count': 299, 'favorited': False, 'retweeted': False, 'lang': 'ko'}, created_at=datetime.datetime(2014, 10, 10, 9, 11, 39), id=520501907983327232, id_str='520501907983327232', text='오랫만에 강릉 나들이..전남주시인의 모모카페에서 커피한잔. 좋네요..그런데 왜?? 사진이 업로드가 자꾸만 에러가나네요 ㅠㅠ', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='파랑새', source_url='http://novly.com/parang', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x1053b9dd0>, _json={'id': 102026929, 'id_str': '102026929', 'name': '유시민', 'screen_name': 'u_simin', 'location': 'korea', 'description': '문필업에 종사하는 정의당 평당원,\r\n청춘의 독서, 국가란 무엇인가, 어떻게 살 것인가 저자', 'url': 'http://t.co/Zc7QTMzj4Y', 'entities': {'url': {'urls': [{'url': 'http://t.co/Zc7QTMzj4Y', 'expanded_url': 'http://usimin.net/', 'display_url': 'usimin.net', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 572710, 'friends_count': 33354, 'listed_count': 14801, 'created_at': 'Tue Jan 05 10:42:07 +0000 2010', 'favourites_count': 21, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 1195, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/6333066 ...
#  Status(_api=<tweepy.api.API object at 0x1053b9dd0>, _json={'created_at': 'Wed Jul 30 07:47:08 +0000 2014', 'id': 494388711421775872, 'id_str': '494388711421775872', 'text': '아, 투표하고 싶다. 우리동네도 재보선 있으면 퇴근길에 투표할 수 있을텐데... 동작, 수원분들 부럽네요. ㅎㅎ', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 102026929, 'id_str': '102026929', 'name': '유시민', 'screen_name': 'u_simin', 'location': 'korea', 'description': '문필업에 종사하는 정의당 평당원,\r\n청춘의 독서, 국가란 무엇인가, 어떻게 살 것인가 저자', 'url': 'http://t.co/Zc7QTMzj4Y', 'entities': {'url': {'urls': [{'url': 'http://t.co/Zc7QTMzj4Y', 'expanded_url': 'http://usimin.net/', 'display_url': 'usimin.net', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 572710, 'friends_count': 33354, 'listed_count': 14801, 'created_at': 'Tue Jan 05 10:42:07 +0000 2010', 'favourites_count': 21, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 1195, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/633306634/tweet_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/633306634/tweet_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 570, 'favorite_count': 352, 'favorited': False, 'retweeted': False, 'lang': 'ko'}, created_at=datetime.datetime(2014, 7, 30, 7, 47, 8), id=494388711421775872, id_str='494388711421775872', text='아, 투표하고 싶다. 우리동네도 재보선 있으면 퇴근길에 투표할 수 있을텐데... 동작, 수원분들 부럽네요. ㅎㅎ', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x1053b9dd0>, _json={'id': 102026929, 'id_str': '102026929', 'name': '유시민', 'screen_name': 'u_simin', 'location': 'korea', 'description': '문필업에 종사하는 정의당 평당원,\r\n청춘의 독서, 국가란 무엇인가, 어떻게 살 것인가 저자', 'url': 'http://t.co/Zc7QTMzj4Y', 'entities': {'url': {'urls': [{'url': 'http://t.co/Zc7QTMzj4Y', 'expanded_url': 'http://usimin.net/', 'display_url': 'usimin.net', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 572710, 'friends_count': 33354, 'listed_count': 14801, 'created_at': 'Tue Jan 05 10:42:07 +0000 2010', 'favourites_count': 21, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 1195, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profil ...
#  Status(_api=<tweepy.api.API object at 0x1053b9dd0>, _json={'created_at': 'Thu Jul 10 05:39:56 +0000 2014', 'id': 487108942581870593, 'id_str': '487108942581870593', 'text': '성은이 하해와 같사옵니다. 꾸벅! RT @newkinch1973: @u_simin 다 고쳤습니다. 초판본을 사서 고칠수 있게 된 것이 기쁩니다. 30년 뒤에 이 책이 고전이 되길.', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'newkinch1973', 'name': "승리엄마. vic's mum", 'id': 415523500, 'id_str': '415523500', 'indices': [22, 35]}, {'screen_name': 'u_simin', 'name': '유시민', 'id': 102026929, 'id_str': '102026929', 'indices': [37, 45]}], 'urls': []}, 'source': '<a href="http://twtkr.com" rel="nofollow">twtkr</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 102026929, 'id_str': '102026929', 'name': '유시민', 'screen_name': 'u_simin', 'location': 'korea', 'description': '문필업에 종사하는 정의당 평당원,\r\n청춘의 독서, 국가란 무엇인가, 어떻게 살 것인가 저자', 'url': 'http://t.co/Zc7QTMzj4Y', 'entities': {'url': {'urls': [{'url': 'http://t.co/Zc7QTMzj4Y', 'expanded_url': 'http://usimin.net/', 'display_url': 'usimin.net', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 572710, 'friends_count': 33354, 'listed_count': 14801, 'created_at': 'Tue Jan 05 10:42:07 +0000 2010', 'favourites_count': 21, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 1195, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/633306634/tweet_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/633306634/tweet_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 261, 'favorite_count': 152, 'favorited': False, 'retweeted': False, 'lang': 'ko'}, created_at=datetime.datetime(2014, 7, 10, 5, 39, 56), id=487108942581870593, id_str='487108942581870593', text='성은이 하해와 같사옵니다. 꾸벅! RT @newkinch1973: @u_simin 다 고쳤습니다. 초판본을 사서 고칠수 있게 된 것이 기쁩니다. 30년 뒤에 이 책이 고전이 되길.', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'newkinch1973', 'name': "승리엄마. vic's mum", 'id': 415523500, 'id_str': '415523500', 'indices': [22, 35]}, {'screen_name': 'u_simin', 'name': '유시민', 'id': 102026929, 'id_str': '102026929', 'indices': [37, 45]}], 'urls': []}, source='twtkr', source_url='http://twtkr.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x1053b9dd0>, _json={'id': 102026929, 'id_str': '102026929', 'name': '유시민', 'screen_name': 'u_simin', 'location': 'korea', 'description': '문필업에 종사하는 정의당 평당원,\r\n청춘의 독서, 국가란 무엇인가, 어떻게 살 것인가 저자', 'url': 'http://t.co/Zc7QTMzj4Y', 'entities': {'url': {'urls': [{'url': 'http://t.co/Zc7QTMzj4Y', 'expanded_url': 'http://usimin.net/', 'display_url': 'usimin.net', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 572710, 'friends_count': 33354, 'listed_count': 14801, 'created_at': 'Tue Jan 05 10:42:07 +0000 2010', 'favourites_count': 21, 'utc_offset': None ...
#  Status(_api=<tweepy.api.API object at 0x1053b9dd0>, _json={'created_at': 'Thu Jul 10 05:03:27 +0000 2014', 'id': 487099760025690113, 'id_str': '487099760025690113', 'text': '&lt;나의 한국현대사&gt;를 구입하신 독자여러분, 초쇄본 오류를 사과드립니다 http://t.co/lnBveh8XOb', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'http://t.co/lnBveh8XOb', 'expanded_url': 'http://www.usimin.net/?p=1166', 'display_url': 'usimin.net/?p=1166', 'indices': [45, 67]}]}, 'source': '<a href="https://dev.twitter.com/docs/tfw" rel="nofollow">Twitter for Websites</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 102026929, 'id_str': '102026929', 'name': '유시민', 'screen_name': 'u_simin', 'location': 'korea', 'description': '문필업에 종사하는 정의당 평당원,\r\n청춘의 독서, 국가란 무엇인가, 어떻게 살 것인가 저자', 'url': 'http://t.co/Zc7QTMzj4Y', 'entities': {'url': {'urls': [{'url': 'http://t.co/Zc7QTMzj4Y', 'expanded_url': 'http://usimin.net/', 'display_url': 'usimin.net', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 572710, 'friends_count': 33354, 'listed_count': 14801, 'created_at': 'Tue Jan 05 10:42:07 +0000 2010', 'favourites_count': 21, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 1195, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/633306634/tweet_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/633306634/tweet_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 316, 'favorite_count': 229, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'ko'}, created_at=datetime.datetime(2014, 7, 10, 5, 3, 27), id=487099760025690113, id_str='487099760025690113', text='&lt;나의 한국현대사&gt;를 구입하신 독자여러분, 초쇄본 오류를 사과드립니다 http://t.co/lnBveh8XOb', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'http://t.co/lnBveh8XOb', 'expanded_url': 'http://www.usimin.net/?p=1166', 'display_url': 'usimin.net/?p=1166', 'indices': [45, 67]}]}, source='Twitter for Websites', source_url='https://dev.twitter.com/docs/tfw', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x1053b9dd0>, _json={'id': 102026929, 'id_str': '102026929', 'name': '유시민', 'screen_name': 'u_simin', 'location': 'korea', 'description': '문필업에 종사하는 정의당 평당원,\r\n청춘의 독서, 국가란 무엇인가, 어떻게 살 것인가 저자', 'url': 'http://t.co/Zc7QTMzj4Y', 'entities': {'url': {'urls': [{'url': 'http://t.co/Zc7QTMzj4Y', 'expanded_url': 'http://usimin.net/', 'display_url': 'usimin.net', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 572710, 'friends_count': 33354, 'listed_count': 14801, 'created_at': 'Tue Jan 05 10:42:07 +0000 2010', 'favourites_count': 21, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 1195, 'lang': None, 'contributors_enabled': False, 'is_translat ...
#  Status(_api=<tweepy.api.API object at 0x1053b9dd0>, _json={'created_at': 'Tue Jul 08 01:09:33 +0000 2014', 'id': 486316120912429056, 'id_str': '486316120912429056', 'text': '아마 한 열흘 정도 있으면 전자책도 나올 겁니다. 감사!^^ RT @PassionLMS: @u_simin 작가님~~\n"나의 한국현대사" 전자책으로 나왔나요...?', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'PassionLMS', 'name': '임명수', 'id': 126222590, 'id_str': '126222590', 'indices': [37, 48]}, {'screen_name': 'u_simin', 'name': '유시민', 'id': 102026929, 'id_str': '102026929', 'indices': [50, 58]}], 'urls': []}, 'source': '<a href="http://twtkr.com" rel="nofollow">twtkr</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 102026929, 'id_str': '102026929', 'name': '유시민', 'screen_name': 'u_simin', 'location': 'korea', 'description': '문필업에 종사하는 정의당 평당원,\r\n청춘의 독서, 국가란 무엇인가, 어떻게 살 것인가 저자', 'url': 'http://t.co/Zc7QTMzj4Y', 'entities': {'url': {'urls': [{'url': 'http://t.co/Zc7QTMzj4Y', 'expanded_url': 'http://usimin.net/', 'display_url': 'usimin.net', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 572710, 'friends_count': 33354, 'listed_count': 14801, 'created_at': 'Tue Jan 05 10:42:07 +0000 2010', 'favourites_count': 21, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 1195, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/633306634/tweet_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/633306634/tweet_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 241, 'favorite_count': 128, 'favorited': False, 'retweeted': False, 'lang': 'ko'}, created_at=datetime.datetime(2014, 7, 8, 1, 9, 33), id=486316120912429056, id_str='486316120912429056', text='아마 한 열흘 정도 있으면 전자책도 나올 겁니다. 감사!^^ RT @PassionLMS: @u_simin 작가님~~\n"나의 한국현대사" 전자책으로 나왔나요...?', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'PassionLMS', 'name': '임명수', 'id': 126222590, 'id_str': '126222590', 'indices': [37, 48]}, {'screen_name': 'u_simin', 'name': '유시민', 'id': 102026929, 'id_str': '102026929', 'indices': [50, 58]}], 'urls': []}, source='twtkr', source_url='http://twtkr.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x1053b9dd0>, _json={'id': 102026929, 'id_str': '102026929', 'name': '유시민', 'screen_name': 'u_simin', 'location': 'korea', 'description': '문필업에 종사하는 정의당 평당원,\r\n청춘의 독서, 국가란 무엇인가, 어떻게 살 것인가 저자', 'url': 'http://t.co/Zc7QTMzj4Y', 'entities': {'url': {'urls': [{'url': 'http://t.co/Zc7QTMzj4Y', 'expanded_url': 'http://usimin.net/', 'display_url': 'usimin.net', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 572710, 'friends_count': 33354, 'listed_count': 14801, 'created_at': 'Tue Jan 05 10:42:07 +0000 2010', 'favourites_count': 21, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, '
 'h': 720, 'resize': 'fit'}}, 'source_status_id': 469649725151399937, 'source_status_id_str': '469649725151399937', 'source_user_id': 2495886864, 'source_user_id_str': '2495886864', 'features': {'small': {'faces': [{'x': 274, 'y': 521, 'h': 55, 'w': 55}, {'x': 102, 'y': 21, 'h': 55, 'w': 55}]}, 'orig': {'faces': [{'x': 291, 'y': 553, 'h': 59, 'w': 59}, {'x': 109, 'y': 23, 'h': 59, 'w': 59}]}, 'medium': {'faces': [{'x': 291, 'y': 553, 'h': 59, 'w': 59}, {'x': 109, 'y': 23, 'h': 59, 'w': 59}]}, 'large': {'faces': [{'x': 291, 'y': 553, 'h': 59, 'w': 59}, {'x': 109, 'y': 23, 'h': 59, 'w': 59}]}}}]}, 'source': '<a href="http://twtkr.com" rel="nofollow">twtkr</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 102026929, 'id_str': '102026929', 'name': '유시민', 'screen_name': 'u_simin', 'location': 'korea', 'description': '문필업에 종사하는 정의당 평당원,\r\n청춘의 독서, 국가란 무엇인가, 어떻게 살 것인가 저자', 'url': 'http://t.co/Zc7QTMzj4Y', 'entities': {'url': {'urls': [{'url': 'http://t.co/Zc7QTMzj4Y', 'expanded_url': 'http://usimin.net/', 'display_url': 'usimin.net', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 572710, 'friends_count': 33354, 'listed_count': 14801, 'created_at': 'Tue Jan 05 10:42:07 +0000 2010', 'favourites_count': 21, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 1195, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg ...
#  Status(_api=<tweepy.api.API object at 0x1053b9dd0>, _json={'created_at': 'Tue May 27 06:25:55 +0000 2014', 'id': 471175446336253952, 'id_str': '471175446336253952', 'text': "즐감요^^RT @hosun1000: '진중권의 정치다방'.유시민,노회찬의 두편의 예고로 꽤 시끄러웠던 정의당의 팟캐스트가 지금 막 출시되었습니다.http://t.co/oBQCnT1bGQ", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'hosun1000', 'name': '천호선', 'id': 67829856, 'id_str': '67829856', 'indices': [8, 18]}], 'urls': [{'url': 'http://t.co/oBQCnT1bGQ', 'expanded_url': 'http://www.podbbang.com/ch/7657', 'display_url': 'podbbang.com/ch/7657', 'indices': [81, 103]}]}, 'source': '<a href="http://twtkr.com" rel="nofollow">twtkr</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 102026929, 'id_str': '102026929', 'name': '유시민', 'screen_name': 'u_simin', 'location': 'korea', 'description': '문필업에 종사하는 정의당 평당원,\r\n청춘의 독서, 국가란 무엇인가, 어떻게 살 것인가 저자', 'url': 'http://t.co/Zc7QTMzj4Y', 'entities': {'url': {'urls': [{'url': 'http://t.co/Zc7QTMzj4Y', 'expanded_url': 'http://usimin.net/', 'display_url': 'usimin.net', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 572710, 'friends_count': 33354, 'listed_count': 14801, 'created_at': 'Tue Jan 05 10:42:07 +0000 2010', 'favourites_count': 21, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 1195, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/633306634/tweet_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/633306634/tweet_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'can_media_tag': True, 'followed_by': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 243, 'favorite_count': 160, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'ko'}, created_at=datetime.datetime(2014, 5, 27, 6, 25, 55), id=471175446336253952, id_str='471175446336253952', text="즐감요^^RT @hosun1000: '진중권의 정치다방'.유시민,노회찬의 두편의 예고로 꽤 시끄러웠던 정의당의 팟캐스트가 지금 막 출시되었습니다.http://t.co/oBQCnT1bGQ", truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'hosun1000', 'name': '천호선', 'id': 67829856, 'id_str': '67829856', 'indices': [8, 18]}], 'urls': [{'url': 'http://t.co/oBQCnT1bGQ', 'expanded_url': 'http://www.podbbang.com/ch/7657', 'display_url': 'podbbang.com/ch/7657', 'indices': [81, 103]}]}, source='twtkr', source_url='http://twtkr.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x1053b9dd0>, _json={'id': 102026929, 'id_str': '102026929', 'name': '유시민', 'screen_name': 'u_simin', 'location': 'korea', 'description': '문필업에 종사하는 정의당 평당원,\r\n청춘의 독서, 국가란 무엇인가, 어떻게 살 것인가 저자', 'url': 'http://t.co/Zc7QTMzj4Y', 'entities': {'url': {'urls': [{'url': 'http://t.co/Zc7QTMzj4Y', 'expanded_url': 'http://usimin.net/', 'display_url': 'usimin.net', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 572710, 'friends_count': 33354, 'listed_count': 14801, 'created_ ...

# %%
my_tweets[0].text
my_tweets[1].user.url
# Out:
# 'http://t.co/Zc7QTMzj4Y'

# %% [markdown]
# 수집하고자 하는 트윗의 갯수를 지정할 수 있다. 이 경우 아이템의 숫자 (items()) 혹은 페이지의 숫자 (pages()) 를 지정한다.
#
# ```
# # Only iterate through the first 200 statuses
# for status in tweepy.Cursor(api.user_timeline).items(200):
#     process_status(status)
#
# # Only iterate through the first 3 pages
# for page in tweepy.Cursor(api.user_timeline).pages(3):
#     process_page(page)
# ```

# %% [markdown]
# ### Handling the rate limit using cursors
#
# 위에서 언급한 것처럼, 많은 양의 트윗을 수집하고자 할 때, **```RateLimitError```** 에러가 발생한다. 이런 경우 페이지를 넘기기 전에 (next()) 에러를 체크하고, **```RateLimitError```** 에러가 발생하면 그 만큼 수집을 멈추었다가 재개하여야 한다. 에러 핸들링을 하지 않으면 프로그램이 멈추고 데이터 수집도 멈춘다.
#
# ```
# def limit_handled(cursor):
#     while True:
#         try:
#             yield cursor.next()
#         except tweepy.RateLimitError:
#             time.sleep(15 * 60)
#
# for follower in limit_handled(tweepy.Cursor(api.followers).items()):
#     process_follower(follower)
# ```

# %% [markdown]
# ### Streaming Tweet Data
#
# Streaming API는 rate limit의 제한이 없어 트윗을 수집할 때 유용하다. 그러나 모든 트윗을 제공하는 것은 아니고, 전체 트윗의 1%만을 random 으로 제공해 준다.
#
# Streaming API를 사용하여 트윗을 수집하려면 다음과 같은 순서를 따른다.
#
# * StreamListener 클래스를 상속받은 lister 클래스를 만든다.
# * Stream 오브젝트를 생성한다.
# * Stream 오브젝트에 Twitter API를 연결한다.

# %% [markdown]
# #### 1. StreamListener 클래스 생성

# %%
import tweepy

class MyListener(tweepy.StreamListener): # tweepy의 StreamListener class를 상속받음
    
    def on_status(self, data): # on_data가 on_status에 data를 넘겨줌
        print(data.text + "\n----")
    
# 이해 안 가도, 그냥 가져다 쓰세요~

# %% [markdown]
# #### 2. Stream 오브젝트 생성하고 Twitter API 연결 (OAuth 설정)

# %%
twitter_stream = tweepy.Stream(auth, MyListener())

# %% [markdown]
# #### 3. Streaming 시작

# %%
twitter_stream.filter(track=['trump', 'korea'])
# jupyter는 메모리관리에 썩 좋지 않음. kernel -> interrupt 해줘야 함. 터미널에서 돌려보도록 하세요!
# '트럼프' 키워드와 '수능' 키워드 올라오는 속도가 다름
# Out:
# RT @KevinMKruse: You can tell Trump is totally innocent because he routinely blocks witnesses and evidence from making it to Congress and h…
# ----
# Trump hosted Zuckerberg for undisclosed dinner at the White House in October https://t.co/sCoZYCeFxw via @nbcnews
# ----
# RT @renato_mariotti: What “insurance” does Giuliani have on Trump?
#
# It’s totally unethical for a lawyer to suggest that he has negative inf…
# ----
# RT @misayeon: ABU Song Festival posted a clip of the artists’ introductions at the festival where they introduced TWICE as Korea’s represen…
# ----
# @vietthanhsports No Trump needs the official stamp of corruption that will come with impeachment. She should includ… https://t.co/LooBiU6lR4
# ----
# RT @OcrazoSnowfake: Did the Whistleblower Change his story?? https://t.co/98X0T1Trhi
# ----
# RT @prayingmedic: 10) President Trump was elected to remove a failed and corrupt political establishment.
# https://t.co/KsjAeOS76d
# ----
# RT @realDonaldTrump: ....ANY DIRECT EVIDENCE THAT PRESIDENT TRUMP DID ANYTHING IMPEACHABLE. No one heard him order a quid pro quo. No one o…
# ----
# RT @lady_sullem: https://t.co/iRZcS85GWG
# 예전에 텀블벅으로 런칭한 애니메이션인데 전세계적으로 흥하고 있는 걸 보니 신기하다
# 한국의 스튜디오 고인돌의 작품! https://t.co/xV5CZSOVAG
# ----
# RT @Mimirocah1: So.... @RudyGiuliani is extorting @realDonaldTrump to make sure Trump doesn’t throw Rudy under the bus for shaking down Ukr…
# @AmbJohnBolton We need the real scoop between Trump and Melania.  Is it a contract marriage now that he's been proven to be a cheat?
# ----
# RT @GN_7kr: 한국 애니메이션 ASMR 계정이래요 이름은 '도기코기' 유튜브에 치면 나오고 외에도 그리는 방법이라던가 굿즈 안내같은 것도 있대요ㅠ.ㅠ 가서 들어봤는데 다 30분씩 되어있고 아가들이 조금씩 다르게 움직여요... 진짜 짱 귀여워.…
# ----
# RT @mmpadellan: Pretty stunning when you realize that a dozen people -- Ambassadors, WH officials, Nat'l Security Officials -- all testifie…
# ----
# RT @Ordinary1World: Trump has been busy wooing &amp; bribing Senate Republicans for the acquittal vote.
#
# If they don’t vote to convict, they wi…
# ----
# RT @misayeon: ABU Song Festival posted a clip of the artists’ introductions at the festival where they introduced TWICE as Korea’s represen…
# ----
# RT @OliverMcGee: Trump Wants “Blacks For Trump” in 2020! Retweet!
#
# @POTUS @realDonaldTrump Beat @HillaryClinton to @WhiteHouse with 8% of B…
# ----
# RT @NYTimesCohen: Fiona Hill and the American Idea. A naturalized American exposes Trump's attack on what America is. https://t.co/hVg6y5Ok…
# ----
# RT @misayeon: ABU Song Festival posted a clip of the artists’ introductions at the festival where they introduced TWICE as Korea’s represen…
# ----
# RT @atrupar: This clip from last night's Hannity is a remarkable example of how Fox News selectively uses short, out of context clips from…
# ----
# @Hoosiers1986 @RepAdamSchiff Hi Bradley. I'm not a Trump person, but I do believe that we need to find our way back… https://t.co/ZavgM27h1s
# ----
# RT @RickshawRoman: They care more about what Trump said to Ukraine than they ever did about those poor lost souls of #Benghazi https://t.co…
# ----
# RT @Shem_Infinite: So now we have the head of the Senate Judiciary Committee (Graham), Finance Committee (Grassley), and Homeland Security…
# ----
# RT @owenawhaley: This story should be getting a lot more attention.
#
# Trump placed sanctions on a company linked to the Chinese government,…
# ----
# RT @realDonaldTrump: ....ANY DIRECT EVIDENCE THAT PRESIDENT TRUMP DID ANYTHING IMPEACHABLE. No one heard him order a quid pro quo. No one o…
# ----
# @VPITV Quieren que vaya Trump a arreglar las tuberías.
# ----
# RT @Cernovich: @EricRWeinstein @AndrewYang @TulsiGabbard @BernieSanders @realDonaldTrump Trump will be fine without a podcast appearance bu…
# ----
# RT @MrMichaelSpicer: the room next door - President Trump and Homelessness
#
# now with subtitles by @vodathan https://t.co/hPN9LWZmDh
# ----
# RT @riotwomennn: Facebook had employees who were embedded with Trump's campaign.
#
# Facebook was paid $85 million that we know of by Trump.…
# ----
# RT @xJuanMed: Im glad the main stream media is finally waking up.  They might improve their reputation by reporting on real corruption and…
# ----
# RT @alexmjordan: 🇺🇸#JordansViewExpress 245🇺🇸
# Let's Make a Deal, America
#
# Door #1: Dems Impeach #Trump (or they'll lose) +
# Un-American #Soci…
# ----
# RT @JerseyGirl_555: MSM lies to us daily, they are fake news! 👇🏻👇🏻👇🏻 from 2015 was President! https://t.co/qT4VnRxzEw
# ----
# RT @JohnJHarwood: Fiona Hill clarified what’s been going on
#
# the party of Reagan, from top to bottom, is helping Russian intelligence disse…
# ----
# RT @realDonaldTrump: ....ANY DIRECT EVIDENCE THAT PRESIDENT TRUMP DID ANYTHING IMPEACHABLE. No one heard him order a quid pro quo. No one o…
# ----
# RT @Megavolts001: #Chalupa
# #Grassley
# #Spygate
# #Ukraine
# Grassley Demand Materials From FBI On Ukrainian DNC Contractor
# DOJ / FBI have mater…
# ----
# RT @AdamSerwer: The most sobering fact of the Trump era is this: American elites are sniveling cowards who set their knees and faces to the…
# ----
# @rihanna @SavageXFenty https://t.co/IDogibSo2g
# ----
# Yes,  Trump is guilty along with his republican enablers that helped him.   No,  it was not about helping America i… https://t.co/2PApqJSKqY
# ----
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# ~/opt/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-951c2000b0b6> in <module>
# ----> 1 twitter_stream.filter(track=['trump', 'korea'])
#       2 # jupyter는 메모리관리에 썩 좋지 않음. kernel -> interrupt 해줘야 함. 터미널에서 돌려보도록 하세요!
#       3 # '트럼프' 키워드와 '수능' 키워드 올라오는 속도가 다름
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     440             else:
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     444                     # Close the connection when no data is returned
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in readinto(self, b)
#     489
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#     493         if self.length is not None:
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     584         try:
#     585             while True:
# --> 586                 chunk_left = self._get_chunk_left()
#     587                 if chunk_left is None:
#     588                     return total_bytes
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in _get_chunk_left(self)
#     552                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     553             try:
# --> 554                 chunk_left = self._read_next_chunk_size()
#     555             except ValueError:
#     556                 raise IncompleteRead(b'')
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in _read_next_chunk_size(self)
#     512     def _read_next_chunk_size(self):
#     513         # Read the next chunk size from the file
# --> 514         line = self.fp.readline(_MAXLINE + 1)
#     515         if len(line) > _MAXLINE:
#     516             raise LineTooLong("chunk size")
#
# ~/opt/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     307                 raise
#     308         except OpenSSL.SSL.WantReadError:
# --> 309             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     310                 raise timeout('The read operation timed out')
#     311             else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     102         return poll_obj.poll(t)
#     103
# --> 104     return bool(_retry_on_intr(do_poll, timeout))
#     105
#     106
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in do_poll(t)
#     100         if t is not None:
#     101             t *= 1000
# --> 102         return poll_obj.poll(t)
#     103
#     104     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %% [markdown]
# #### 4. json 파일로 저장할 수 있도록 MyListener 클래스 수정

# %%
class MyListener(tweepy.StreamListener):
    
    def on_data(self, data):
        try:
            with open('tweet_stream.json', 'a') as file: # 'a' = append
                file.write(data) # 여태 수집한 data들을 수집
                print(data) # 모니터링 
                return True 
        except BaseException as e: 
            print("Error on_data: {}".format(str(e)))
        return True

# %%
twitter_stream = tweepy.Stream(auth, MyListener())
twitter_stream.filter(track=['trump', 'korea'])
# Out:
# {"created_at":"Sun Nov 24 05:56:44 +0000 2019","id":1198480548806590466,"id_str":"1198480548806590466","text":"RT @Jordan_Sather_: Once I heard President Trump say we\u2019re \u201cready to unlock the mysteries of space\u201d in his inauguration speech, I knew shit\u2026","source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":490866532,"id_str":"490866532","name":"MAGNA STILLMAN","screen_name":"distiller60","location":null,"url":null,"description":"Gun totin right wing nationalist populist! \u2018Draw a red line under the nose of the leftist socialists. Then bust them in the face while pushing them back!\u2019","translator_type":"none","protected":false,"verified":false,"followers_count":1346,"friends_count":976,"listed_count":1,"favourites_count":93505,"statuses_count":75494,"created_at":"Mon Feb 13 00:27:24 +0000 2012","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/431662607901024256\/br3jxGzQ_normal.jpeg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/431662607901024256\/br3jxGzQ_normal.jpeg","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Sun Nov 24 03:16:09 +0000 2019","id":1198440139657138176,"id_str":"1198440139657138176","text":"Once I heard President Trump say we\u2019re \u201cready to unlock the mysteries of space\u201d in his inauguration speech, I knew\u2026 https:\/\/t.co\/HoNAIbWhyo","source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","truncated":true,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":835627637049450497,"id_str":"835627637049450497","name":"Jordan Sather","screen_name":"Jordan_Sather_","location":null,"url":"https:\/\/www.jordansather.com","description":"I'm just here for the Awakening. \nYouTube #1: http:\/\/bit.ly\/2SK460d\nYouTube #2: http:\/\/bit.ly\/2qFwebh\ntips & tricks: jordan.sather@protonmail.com","translator_type":"none","protected":false,"verified":false,"followers_count":106742,"friends_count":1108,"listed_count":815,"favourites_count":14534,"statuses_count":15256,"created_at":"Sat Feb 25 23:08:48 +0000 2017","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1074303464652455936\/_TIDfL26_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/1074303464652455936\/_TIDfL26_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/835627637049450497\/1539571418","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent ...
#
# {"created_at":"Sun Nov 24 05:56:44 +0000 2019","id":1198480549003837441,"id_str":"1198480549003837441","text":"RT @HKrassenstein: BREAKING:  Washington National players Sean Doolittle, Anthony Rendon, Joe Ross, Javy Guerra, Wilmer Difo, Victor Robles\u2026","source":"\u003ca href=\"http:\/\/twitter.com\
+0000 2011","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"033C82","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme15\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme15\/bg.png","profile_background_tile":false,"profile_link_color":"20285C","profile_sidebar_border_color":"FFFFFF","profile_sidebar_fill_color":"EBEBEB","profile_text_color":"333333","profile_use_background_image":false,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1045473448783466496\/XnZoIj-Q_normal.jpg","p ...
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# ~/opt/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-ca48dc9bdf25> in <module>
#       1 twitter_stream = tweepy.Stream(auth, MyListener())
# ----> 2 twitter_stream.filter(track=['trump', 'korea'])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     440             else:
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     444                     # Close the connection when no data is returned
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in readinto(self, b)
#     489
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#     493         if self.length is not None:
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     584         try:
#     585             while True:
# --> 586                 chunk_left = self._get_chunk_left()
#     587                 if chunk_left is None:
#     588                     return total_bytes
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in _get_chunk_left(self)
#     552                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     553             try:
# --> 554                 chunk_left = self._read_next_chunk_size()
#     555             except ValueError:
#     556                 raise IncompleteRead(b'')
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in _read_next_chunk_size(self)
#     512     def _read_next_chunk_size(self):
#     513         # Read the next chunk size from the file
# --> 514         line = self.fp.readline(_MAXLINE + 1)
#     515         if len(line) > _MAXLINE:
#     516             raise LineTooLong("chunk size")
#
# ~/opt/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     307                 raise
#     308         except OpenSSL.SSL.WantReadError:
# --> 309             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     310                 raise timeout('The read operation timed out')
#     311             else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     102         return poll_obj.poll(t)
#     103
# --> 104     return bool(_retry_on_intr(do_poll, timeout))
#     105
#     106
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in do_poll(t)
#     100         if t is not None:
#     101             t *= 1000
# --> 102         return poll_obj.poll(t)
#     103
#     104     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %% [markdown]
# (참고1) ```on_status vs. on_data```
#
# ```on_status```는 데이터를 tweepy object 형태로 return한다. 따라서 data.text와 같은 notation이 가능하다. 하지만 ```on_data```는 데이터를 str로 return 한다. 우리는 데이터를 .json 파일로 저장할 것이기 때문에 tweepy object보다는 str로 저장하여야 한다. 따라서 두번째 수정된 코드에서는 ```on_data```를 사용하였다.
#
# (참고2) ```on_status vs. on_data```
#
# 두개의 메소드는 StreamListener에 구현되어 있다. 클래스를 상속 받으면 부모 클래스에 구현된 메소드를 재정의(override)해서 사용할 수 있다.

# %% [markdown]
# ### 터미널에서 프로그램 실행
#
# jupyter notebook이 편리하긴 하지만 어떤 경우에는 터미널에서 프로그램을 실행하여야 한다. 스트리밍한 데이터를 저장하는 프로그램은 계속 데이터를 받아오기 때문에 jupyter notebook에서 실행하면 메모리 로드가 많아 작동불능 상태에 빠지기 쉽다. 따라서 이 경우 터미널에서 프로그램을 실행시킨다.
#
# * 첫번째 스트리밍 코드는 twitter-stream.py 로 저장되어 있다.
# * 수정된 두번째 스트리밍 코드는 twitter-stream-save.py로 저장되어 있다.
#
# 실행은 터미널에서 다음과 같이 한다.
#
# * python twitter-stream-save.py
#
# 프로그램의 종료는 CTRL-C 를 누른다

# %% [markdown]
# ### JSON 파일 불러오기

# %%
import json

json_data = []
with open("tweet_stream.json") as file:
    data = file.readlines()
    for d in data:
        json_data.append(json.loads(d)) # dict file 구축
        # json.loads: json 형식의 string을 python dictionary 형식으로 변경

# %%
i = 0
for tweet in json_data:
    if ("text" in tweet) and ("user" in tweet):
        print(str(i) + " - " + tweet["user"]["name"] + " :: " + tweet["text"])
        print("---")
        i = i + 1
# Out:
# 0 - MAGNA STILLMAN :: RT @Jordan_Sather_: Once I heard President Trump say we’re “ready to unlock the mysteries of space” in his inauguration speech, I knew shit…
# ---
# 1 - Manya Zuba :: RT @HKrassenstein: BREAKING:  Washington National players Sean Doolittle, Anthony Rendon, Joe Ross, Javy Guerra, Wilmer Difo, Victor Robles…
# ---
# 2 - Eric Wong :: RT @TheJihyeLee: March from Seoul City Hall to Chinese Embassy in South Korea, students chanting, “stand for freedom, stand with Hong Kong”…
# ---
# 3 - 🏄Julia Sugarbaker🏄🌊 #VoteBlueNoMatterWho 🌊 :: RT @dukewindsor388: WTF do Trump supporters say to their sons when their school calls that he grabbed a girl by her privates . . . or he ma…
# ---
# 4 - John Howarth :: RT @jasoninthehouse: Jason Chaffetz: Liberal media trying to 'diminish' Trump, downplay seriousness of IG Horowitz's FISA report | Fox News…
# ---
# 5 - g(r)ey :: @shaneqsmith Being anti Trump doesn’t give them ethical license to show bias within the DNC primary.
# ---
# 6 - Janet Patti Muller :: RT @File411: Has the OGE certified @SecretaryRoss Financials...yet?
# Asking for a few million friends who are growing frustrated by the blat…
# ---
# 7 - Deplorable Viki ⭐⭐⭐💗 🇺🇸🕯Q :: RT @storfer_herman: Again and again and again...
# Why the dems, social media corps, MSM, and leftists HATE us that back and support our POTU…
# ---
# 8 - Mary EllenCaddell :: RT @PattyArquette: Remember when Trump wanted Putin and Russia to work with our cyber security team? MAGA ? https://t.co/ZMPWx5HGiQ
# ---
# 9 - eme :: RT @BryanESmithJr: I voted for George H. W. Bush, twice.  I voted for his kid, "W", twice.
#
# The first time I heard "New World Order" was wh…
# ---
# 10 - Cloudydays16 :: RT @espiers: If you're gonna cover chills/fever with this level of urgency (&amp; I know she's 86, so can be serious) it would be nice to see t…
# ---
# 11 - LoveTrumpsHate :: RT @thehill: Trump White House keeps Democrats from hearing from critical impeachment witnesses https://t.co/nzqUzhcOO8 https://t.co/rF0RZG…
# ---
# 12 - Karen Johnson-Hulit :: RT @olgaNYC1211: @IgnatiusPost @nytimes Eye popping?? Trumps presidency is a Russian Intel operation with a very willing trump who has been…
# ---
# 13 - ThinkCenter68 :: RT @Megavolts001: #Chalupa
# #Grassley
# #Spygate
# #Ukraine
# Grassley Demand Materials From FBI On Ukrainian DNC Contractor
# DOJ / FBI have mater…
# ---
# 14 - 🇺🇸 Cris 🇵🇷 :: RT @parscale: Re: Google
#
# Political elites &amp; Big Tech want to rig elections - Dem primary &amp; 2020 included. They’re targeting Trump because…
# ---
# 15 - DW :: RT @SenSchumer: President Trump's words do not reflect what Americans think about the Chinese Communist Party's oppressive policies toward…
# ---
# 16 - Gray Ellis :: RT @B52Malmet: Over 50 of 53 Republican Senators have been to lunch at the White House since #ImpeachmentInquiry began. Others are being wi…
# ---
# 17 - Mina Mochizuki :: RT @HvonSpakovsky: Canaparo &amp; von Spakovsky: Did Trump critic Rep. Rashida Tlaib violate campaign finance laws and ethics rules? https://t.…
# ---
# 18 - 7-11 :: RT @Jim_Jordan: “Jim Jordan says facts are on Trump's side after week of public impeachment hearings”
#
# @BretBaier https://t.co/gBPNYvYPjW
# ---
# 19 - nmfa :: RT @CREWcrew: If this week has shown us anything it's that there's a dire need for ethics reform.
#
# Here's one idea: creating an inspector…
# ---
# 20 - Rico1 :: RT @realDerekUtley: Barron Trump is a solid 2 inches taller than @realDonaldTrump. Here’s like 6’5 at 13. https://t.co/GTnLrCPerv
# ---
# 21 - Sally Claus :: RT @TeamPelosi: From "everyone was in the loop" in the Trump bribery scheme to "we followed the President’s orders" -- the news coverage ac…
# ---
# 22 - Impatient Cat 🇺🇸 #BetoForever 🇺🇸 Ⓜ️🍑🤡 :: @SafetyPinDaily #SirAlert #SirStory #LyingTrump
#
# "Trump continued to disparage former U.S. ambassador to Ukraine Y… https://t.co/Pn8Be2V9xu
# ---
# 23 - BUMBLEBEE #Trump2020 :: RT @katsund4: 😡 I would really like to know how this EVIL MAN has gotten away with this for so long  😡😡👇👇
#
# Soros 'dark money' behind ads ur…
# ---
# 24 - Marctanner :: RT @RealSaavedra: CNN's Don Lemon asks Joe Biden about his health, noting that Michael Bloomberg has entered the race due to concerns on Bi…
# ---
# 25 - cloudbelle :: RT @TomJChicago: 4 Obama’s doctor called out what has been apparent &amp; continually worsening. Trump has a serious neurological issue. Note h…
# ---
# 26 - Donna Castel :: RT @GregHillTX: First ⁦⁦@AOC⁩, then ⁦@Ilhan⁩, now ⁦@RashidaTlaib⁩?
#
# I thought no one was above the law? This is why we have to clean up Was…
# ---
# 27 - 💫HANZADE💫GÜL🌹AK :: RT @54FuRKaN_: Bu video da Kılıçdaroğlu CeHaPesi   için gelsin.
#
# Büyük Lider Recep Tayyip Erdoğan:
#
# Mektupları Trump'a iade ettim.
#
# #Erdo…
# ---
# 28 - Pyramid196 :: RT @Jennydan26: This is why they hate Stone! He called it two years ago. Legend! https://t.co/gemqcrDiMF
# ---
# 29 - Thomas Gregg :: RT @kenvogel: NEW: RUDY GIULIANI briefed MIKE POMPEO in late March on claims about BIDEN, YOVANOVITCH, etc.
#
# @SecPompeo called back &amp; asked…
# ---
# 30 - King Kong Ickki, the Woulfmann! :: RT @atrupar: Trump claims that if he hadn't fired Comey, "I would have been in some trouble right now, because they were coming after me ..…
# ---
# 31 - Cathy Kwasigroch :: RT @zeusFanHouse: #Trump Vows To Release Financial Records
#
# "What they r doing is not legal.But I’m clean&amp;when I release my financial state…
# ---
# 32 - NewsOnline :: @rihanna @PrimeVideo @djkhaled @halsey @BigSean @Migos @fatjoe @ASAPferg @myfabolouslife @TierraWhack https://t.co/IDogibSo2g
# ---
# 33 - Pauline :: This S.O.B needs to Go Now....
# IMPEACH TRUMP....
# ---
# 34 - Jackson Street Blues :: Lets make shit up as we go
# ---
# 35 - Ashiqur Rahman :: Are you looking for  web design , wordpress , e-commerce or logo design ?
# please check my link… https://t.co/HVJX6AGmPt
# ---
# 36 - Peggy Rothschild :: RT @CREWcrew: Remember this? Taxpayers spent nearly $250,000 on hotels, airfare and other costs for Secret Service protection for Eric and…
# ---
# 37 - We have entered the Twilight Zone :: RT @AngrierWHStaff: McConnell has already made it clear to Trump that the GOP doesn’t have the votes to dismiss the trial outright.
#
# McCon…
# ---
# 38 - LJNews :: If #PresidentTrump appeals to men with fragile masculinity, will #PeteButtigieg beat #Trump or join #POTUS?
# https://t.co/BCyGZoEsRW
# ---
# 39 - JOCKER :: What does America mean to you? Who is Donald trump?The book is devoted to modern us politics in the historical past… https://t.co/ib1EOe3Jvy
# ---
# 40 - obsession🔥 :: RT @Exofanbase: [INFO] 191124 EXO has safely arrived at ICN Airport Seoul, South Korea🛬🇰🇷 Rest well boys💙
#
# #EXO #엑소 @weareoneEXO @exooneare…
# ---
# 41 - eliii ❥ :: RT @mvriaf: Don’t disrespect my man Don Francisco like that https://t.co/Eg1lACr4WJ
# ---
# 42 - Patriot4ever :: RT @NevadaJack2: Marie Yovanovitch was “an Obama person” who refused to hang President Trump’s portrait in the U.S. Embassy after he won th…
# ---
# 43 - BrokenPromisedLand :: RT @TomJChicago: 4 Obama’s doctor called out what has been apparent &amp; continually worsening. Trump has a serious neurological issue. Note h…
# ---
# 44 - L1sten :: RT @realDerekUtley: Barron Trump is a solid 2 inches taller than @realDonaldTrump. Here’s like 6’5 at 13. https://t.co/GTnLrCPerv
# ---
# 45 - RosemaryMelendez :: RT @1776Stonewall: RBG back in hospital. The poor woman desperately needs to retire, but the Dems won't allow her. They're terrified of Tru…
# ---
# 46 - LB :: RT @aQuoteAday: "Frozen 2" movie tickets in Korea https://t.co/nDlnXhdulc
# ---
# 47 - Arkansas Lady :: RT @JulieReichwein1: President Trump to hold rally in South Florida before Thanksgiving &amp; Laura Loomer his Future Congressswoman for Florid…
# ---
# 48 - Piox :: SANA ALL NAG KOREA!
# ---
# 49 - theRealDennisJDunbar :: Where do I sign to support the impeachment and for citing You and Trump for treason?
# ---

# %% [markdown]
# ## 2. OpenAPI 를 이용하여 데이터 크롤링
#
# 지금까지 살펴본 Twitter나 Facebook은 해당 서비스의 데이터 크롤링을 위한 파이썬 라이브러리를 이용하여 데이터를 수집할 수 있었다. 이들 라이브러리는 Twitter나 Facebook이 제공하는 OpenAPI에 맞게 개발되었다. 모든 서비스를 위한 라이브러리가 제공되는지는 않기 때문에 특정 서비스의 OpenAPI를 이용하려면 OpenAPI가 제공하는 방식에 맞게 프로그램을 설계하고 데이터를 수집한다.
#
# 대개 OpenAPI는 다음과 같은 형식의 URL을 이용하여 필요한 자료를 API 서버에 request 한다. (call)
# * (포맷) http://web-address/api-name?param1=xxx&param2=xxx&param3=xxx
# * (사례) http://api.openweathermap.org/data/2.5/weather?q=Seoul&units=metric&appid=yourkey
#
# API서버가 call을 받으면 다음과 같이 JSON 포맷으로 결과를 반환한다. (response)
# ```
# {
#     "coord":{"lon":126.98,"lat":37.57},
#     "weather":[
#          {"id":701,"main":"Mist","description":"mist","icon":"50d"},
#          {"id":500,"main":"Rain","description":"light rain","icon":"10d"},
#          {"id":721,"main":"Haze","description":"haze","icon":"50d"}
#     ],
#     "base":"stations",
#     "main":{"temp":11.01,"pressure":1022,"humidity":43,"temp_min":10,"temp_max":12},
#     "visibility":10000,
#     "wind":{"speed":3.1,"deg":360},
#     "clouds":{"all":90},
#     "dt":1541917800,
#     "sys":{"type":1,"id":7668,"message":0.0054,"country":"KR","sunrise":1541887637,"sunset":1541924664},
#     "id":1835848,
#     "name":"Seoul",
#     "cod":200
# }
# ```
#
# 이와 같이 API를 사용하기 위해서는 공개된 OpenAPI라 하더라도 개발자로 등록을 해야 한다.
#
# 개발자로 등록을 한 후에는 데이터 수집을 위해 제작할 application을 등록한다.
#
# application을 등록하면 보통 app-key라는 것을 주는데, 이것은 일종의 아이디-패스워드이다. 즉, 누가 접속을 해서 데이터를 수집해가는 지를 서버에 알려주는 역할을 하며, 또한 서버 입장에서 데이터를 수집하는 앱의 트래픽을 콘트롤하기도 한다. (대개의 경우 call 숫자가 정해져 있다.)
#
# 본 예제에서는 openweathermap.org에서 제공하는 공개 데이터를 사용해 보고자 한다. 개발자 등록과 앱 등록은 슬라이드를 참고하자.

# %% [markdown]
# ### 앱 기본 설정
#
# app_key와 base_url 등 기본 설정을 한다.

# %%
import urllib.request
import json
   
app_key  = "781da3bc7b2aeb07cebe04999a760842"
loc      = "Seoul"
base_url = "http://api.openweathermap.org/data/2.5/weather?q={}&units=metric&appid={}".format(loc, app_key)

print(base_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?q=Seoul&units=metric&appid=781da3bc7b2aeb07cebe04999a760842

# %% [markdown]
# ### 현재 날씨

# %%
weather_data = ""
with urllib.request.urlopen(base_url) as response:
    weather_data = json.loads(response.read().decode("utf-8"))

# %% [markdown]
# #### 데이터 확인

# %%
weather_data
# Out:
# {'coord': {'lon': 126.98, 'lat': 37.57},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02d'}],
#  'base': 'stations',
#  'main': {'temp': 14.9,
#   'pressure': 1013,
#   'humidity': 54,
#   'temp_min': 14,
#   'temp_max': 16},
#  'visibility': 10000,
#  'wind': {'speed': 4.1, 'deg': 290, 'gust': 6.7},
#  'clouds': {'all': 20},
#  'dt': 1573455957,
#  'sys': {'type': 1,
#   'id': 5501,
#   'country': 'KR',
#   'sunrise': 1573423609,
#   'sunset': 1573460720},
#  'timezone': 32400,
#  'id': 1835848,
#  'name': 'Seoul',
#  'cod': 200}

# %% [markdown]
# ### 반환되는 날씨 데이터의 정보는 다음을 참고해서 해석하자.
# https://openweathermap.org/current
# https://openweathermap.org/weather-conditions
#
# (참고) `&lang=kr`를 URL에 넣어주면 한글로 데이터를 반환한다.

# %%
humidity = weather_data["main"]["humidity"]
temp = weather_data["main"]["temp"]
cloud = weather_data["clouds"]["all"]
wind = weather_data["wind"]["speed"]
visibility = weather_data["visibility"]
print("습도: {}%".format(humidity))
print("현재기온: {}도".format(temp))
print("구름이 {}% 덮여있고 풍속은 {}m/s입니다.".format(cloud, wind))
print("현재 가시거리는 {}km입니다.".format(visibility/1000))
# Out:
# 습도: 54%
# 현재기온: 14.9도
# 구름이 20% 덮여있고 풍속은 4.1m/s입니다.
# 현재 가시거리는 10.0km입니다.

# %% [markdown]
# ### UNIX Timestamp
#
# 유닉스 운영체계에서 자체적으로 시각을 나타내기 위해 사용하는 포맷을 Unix Timestamp 라고 한다. POSIX 나 Epoch 라고 부르기도 한다. 1970년 1월 1일 0시 0분 0초 (UTC: 협정 세계시) 부터 시작하고 음수로 표현되면 그 이전 시간을 의미한다. 32비트로 표현하며 1970년 1월 1일 부터 몇초가 지났는지를 표현한다.
#
# * 예: 1541922737 seconds since Jan 01 1970. (UTC)
# * https://www.unixtimestamp.com/
#
# UNIX Timestamp 를 변환하는 방법은 다음과 같다.

# %%
from datetime import datetime

sunrise = weather_data["sys"]["sunrise"]
sunset = weather_data["sys"]["sunset"]

print(datetime.fromtimestamp(sunrise).strftime('%Y-%m-%d %H:%M:%S'))
print(datetime.fromtimestamp(sunset).strftime('%Y-%m-%d %H:%M:%S'))

print("오늘 일출시간은 {}이고, 일몰시간은 {}입니다.".format(
    datetime.fromtimestamp(sunrise).strftime('%H시 %M분'),
    datetime.fromtimestamp(sunset).strftime('%H시 %M분')))

# locale 에러 시 strftime(~).encode().decode("unicode-escape")
# Out:
# 2019-11-11 07:06:49
# 2019-11-11 17:25:20
# 오늘 일출시간은 07시 06분이고, 일몰시간은 17시 25분입니다.

# %% [markdown]
# ### 미세먼지 정보

# %% [markdown]
# 미세먼지 정보를 가져와보자.
#
# 미세먼지와 관련된 정보는 다음의 API를 활용할 예정이다.
#
# * http://data.seoul.go.kr/dataList/datasetView.do?infId=OA-1204&srvType=A&serviceKind=1
#
# 데이터 수집을 위해서는 인증키(위의 App Key와 유사)을 받아야 하는데, 인증키 신청 버튼을 눌러 발급받도록 하자. 몇가지 form을 작성하면 키가 발급된다.
#
# 도큐멘테이션에 나와았는 API의 사용은 다음과 같다.
#
# * http://openAPI.seoul.go.kr:8088/(인증키)/xml/ForecastWarningMinuteParticleOfDustService/1/1/
#
# 위의 URL의 (인증키) 부분에는 발급받은 인증키를 넣도록 하자.
#
# 현재 이 URL은 XML 형태로 데이터를 제공한다. xml을 json으로 바꿔서 json 형식으로 데이터를 받아보자.

# %%
import urllib.request
import json
   
mykey  = "654479766c776c643538765a62746a" # 이곳의 key를 발급받으세요
base_url = "http://openAPI.seoul.go.kr:8088/{}/json/ForecastWarningMinuteParticleOfDustService/1/1/ ".format(mykey)

# print(base_url)
fine_dust_data = ""
with urllib.request.urlopen(base_url) as response:
    fine_dust_data = json.loads(response.read().decode("utf-8"))

# %%
fine_dust_data
# Out:
# {'RESULT': {'CODE': 'INFO-200', 'MESSAGE': '해당하는 데이터가 없습니다.'}}

# %%
from datetime import datetime

time_observation = datetime.strptime(fine_dust_data["ForecastWarningMinuteParticleOfDustService"]["row"][0]["APPLC_DT"], "%Y%m%d%H%M")
dust_grade = fine_dust_data["ForecastWarningMinuteParticleOfDustService"]["row"][0]["CAISTEP"]
dust_grade

# · 0∼30 : 좋음 · 31∼80 : 보통 · 81∼150 : 나쁨 · 151 이상 : 매우 나쁨
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-8e1944210bde> in <module>
#       1 from datetime import datetime
#       2
# ----> 3 time_observation = datetime.strptime(fine_dust_data["ForecastWarningMinuteParticleOfDustService"]["row"][0]["APPLC_DT"], "%Y%m%d%H%M")
#       4 dust_grade = fine_dust_data["ForecastWarningMinuteParticleOfDustService"]["row"][0]["CAISTEP"]
#       5 dust_grade
#
# KeyError: 'ForecastWarningMinuteParticleOfDustService'

# %%
warning = ""
if dust_grade == "매우 나쁨":
    warning = "외출을 자제하시는 것이 좋습니다."
elif dust_grade == "나쁨":
    warning = "외출시 꼭 마스크를 착용하세요."
elif dust_grade == "보통":
    warning = "마음껏 외출하세요."
else:
    warning = "너무 좋은 날씨네요. 마음껏 외출하세요 :)"
message = "{}년 {}월 {}일 {}시 현재, 미세먼지 수준은 {}입니다. ".format(time_observation.year, time_observation.month, time_observation.day, time_observation.hour, dust_grade)

print(message + warning)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-c7126124e182> in <module>
#       1 warning = ""
# ----> 2 if dust_grade == "매우 나쁨":
#       3     warning = "외출을 자제하시는 것이 좋습니다."
#       4 elif dust_grade == "나쁨":
#       5     warning = "외출시 꼭 마스크를 착용하세요."
#
# NameError: name 'dust_grade' is not defined

# %% [markdown]
# ## 4. Advanced Web Crawling
#
# 지난 시간에 다뤘던 것처럼, BeautifulSoup을 이용하여 HTML 내의 특정 요소를 찾아 데이터를 추출할 수 있다. 그러나 최근에 만들어지는 웹사이트의 경우, AJAX 를 사용하여 데이터를 불러오는 경우가 많아, 필요한 데이터를 추출하기 어려운 경우가 있다. 이런 경우, 브라우저에서 제공하는 developer tool 을 사용하여 데이터 소스를 찾아 직접 데이터를 다운로드 하기도 한다. (슬라이드 참조)

# %% [markdown]
# ### 뉴스 사이트 (media daum)에서 기사의 본문을 추출

# %%
from bs4 import BeautifulSoup
import urllib.request

url = "https://news.v.daum.net/v/20181111190005301"
doc = ""
with urllib.request.urlopen(url) as url:
    doc = url.read()

# %%
soup = BeautifulSoup(doc, "html.parser")

# %%
news_article = soup.find_all("div", class_="article_view")
news_article

# %%
news_article[0].text

# %% [markdown]
# ### 뉴스사이트에서 기사의 댓글을 추출

# %%
comments = soup.find_all("ul", class_="list_comment")

# %%
comments

# %% [markdown]
# 위에서 기사의 본문을 추출한 것과 동일한 방법으로 기사의 댓글을 추출하고자 하였다. 브라우저의 inspector에서 보았을 때 해당 블락은 ```<ul class="list_comment">```로 정의되어 있었다. 그러나 실제로 해당 요소는 검색이 되지 않았다. 이는 페이지 소스에 이 요소가 포함되지 않았기 때문이다. 해당 요소는 page 가 모두 로딩된 후, javascript를 이용해서 페이지에 **삽입**된다. 따라서 이런 경우 데이터 수집이 불가능하다.
#
# 삽입되는 해당요소가 무엇인지를 찾기 위해서는 브라우저가 제공하는 개발자 도구에서 해당 요소를 삽입하는 코드를 찾아야 한다.
# (슬라이드)

# %% [markdown]
# ### JSON으로 댓글 추출하기
#
# 추출한 댓글 삽입 코드의 주소: https://comment.daum.net/apis/v1/posts/36628933/comments?parentId=0&offset=0&limit=3&sort=RECOMMEND

# %%
import json

json_url = "https://comment.daum.net/apis/v1/posts/36628933/comments?parentId=0&offset=0&limit=3&sort=RECOMMEND"
with urllib.request.urlopen(json_url) as url:
    json_doc = url.read().decode("utf-8")
    json_data = json.loads(json_doc)
json_data
# Out:
# [{'id': 308637472,
#   'userId': 21182555,
#   'postId': 36628933,
#   'forumId': -99,
#   'parentId': 0,
#   'type': 'COMMENT',
#   'status': 'S',
#   'flags': 256,
#   'content': '도대체 법을 만든다는 놈들\n대가리속엔 뭐가들었는지...',
#   'createdAt': '2018-11-11T19:26:52+0900',
#   'updatedAt': '2018-11-11T19:26:52+0900',
#   'childCount': 41,
#   'likeCount': 2128,
#   'dislikeCount': 87,
#   'recommendCount': 2041,
#   'user': {'id': 21182555,
#    'status': 'S',
#    'type': 'USER',
#    'flags': 0,
#    'icon': 'https://t1.daumcdn.net/profile/P8ky.gyBV9I0',
#    'url': '',
#    'username': 'DAUM:Cjzb9',
#    'roles': 'ROLE_USER,ROLE_DAUM,ROLE_IDENTIFIED',
#    'providerId': 'DAUM',
#    'providerUserId': 'Cjzb9',
#    'displayName': '수구꼴통 참수',
#    'description': '',
#    'commentCount': 4583}},
#  {'id': 308637027,
#   'userId': 20543505,
#   'postId': 36628933,
#   'forumId': -99,
#   'parentId': 0,
#   'type': 'COMMENT',
#   'status': 'S',
#   'flags': 4352,
#   'content': '100만원씩 합시다. 1000만원도 좋고.',
#   'createdAt': '2018-11-11T19:24:47+0900',
#   'updatedAt': '2018-11-11T19:24:47+0900',
#   'childCount': 58,
#   'likeCount': 1737,
#   'dislikeCount': 308,
#   'recommendCount': 1429,
#   'user': {'id': 20543505,
#    'status': 'S',
#    'type': 'USER',
#    'flags': 0,
#    'icon': 'https://k.kakaocdn.net/dn/KMfJp/btqzH0M4DuS/YS2SkuLQXZ4dK96OXSLbF1/img_110x110.jpg',
#    'username': 'KAKAO:563286464',
#    'roles': 'ROLE_USER,ROLE_KAKAO,ROLE_IDENTIFIED',
#    'providerId': 'KAKAO',
#    'providerUserId': '25864808',
#    'displayName': '한만형',
#    'description': '',
#    'commentCount': 1090}},
#  {'id': 308638072,
#   'userId': -18247746,
#   'postId': 36628933,
#   'forumId': -99,
#   'parentId': 0,
#   'type': 'COMMENT',
#   'status': 'S',
#   'flags': 256,
#   'content': '멀쩡한 놈들이 상습적으로\n하는경우가 허다하다\n백만원으로 올리자',
#   'createdAt': '2018-11-11T19:29:34+0900',
#   'updatedAt': '2018-11-11T19:29:34+0900',
#   'childCount': 21,
#   'likeCount': 1074,
#   'dislikeCount': 111,
#   'recommendCount': 963,
#   'user': {'id': -18247746,
#    'status': 'S',
#    'type': 'USER',
#    'flags': 0,
#    'icon': 'https://t1.daumcdn.net/profile/EqtYGdqF3GU0',
#    'url': '',
#    'username': 'DAUM:1ez4u',
#    'roles': 'ROLE_USER,ROLE_DAUM,ROLE_IDENTIFIED',
#    'providerId': 'DAUM',
#    'providerUserId': '1ez4u',
#    'displayName': '하늘',
#    'description': '',
#    'commentCount': 734}}]

# %%
for data in json_data:
    print(data['user']['displayName'])
    print(data['content'])
    print(data['likeCount'], data['dislikeCount'])
    print("--")
# Out:
# 수구꼴통 참수
# 도대체 법을 만든다는 놈들
# 대가리속엔 뭐가들었는지...
# 2128 87
# --
# 한만형
# 100만원씩 합시다. 1000만원도 좋고.
# 1737 308
# --
# 하늘
# 멀쩡한 놈들이 상습적으로
# 하는경우가 허다하다
# 백만원으로 올리자
# 1074 111
# --

# %% [markdown]
# ```parentId=0&offset=0&limit=3``` 의 패러미터 값을 조정하여 더 많은 데이터 수집 가능. 예를 들어 limit은 보여지는 댓글의 갯수를 얘기함.
#
# limit을 100개로 고치고 프로그램을 다시 실행해 보자.

# %%
json_url = "https://comment.daum.net/apis/v1/posts/36628933/comments?parentId=0&offset=0&limit=100&sort=RECOMMEND"
with urllib.request.urlopen(json_url) as url:
    json_doc = url.read().decode("utf-8")
    json_data = json.loads(json_doc)
    
for data in json_data:
    print(data['user']['displayName'])
    print(data['content'])
    print(data['likeCount'], data['dislikeCount'])
    print("--")
